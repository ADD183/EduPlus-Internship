# %%
import numpy as np

# %%
mat1=np.array([[1,2],[3,4]])
mat2=np.array([[5,6],[7,8]])
mat1
# Out:
# array([[1, 2],
#        [3, 4]])

# %%
mat2
# Out:
# array([[5, 6],
#        [7, 8]])

# %%
#Multiplication
np.dot(mat1,mat2)
# Out:
# array([[19, 22],
#        [43, 50]])

# %%
#Transpose
mat1.T
# Out:
# array([[1, 3],
#        [2, 4]])

# %%
#determinants
np.linalg.det(mat1)
# Out:
# np.float64(-2.0000000000000004)

# %%
#Inverse
np.linalg.inv(mat1)
# Out:
# array([[-2. ,  1. ],
#        [ 1.5, -0.5]])

# %%
original=np.array([1,2,3,4,5,6])
view=original.view()
copy=original.copy()

original[0]=99

print("Original Array:",original)
print("View Array (After changes):",view)
print("Copy Array:",copy)
# Out:
# Original Array: [99  2  3  4  5  6]
# View Array (After changes): [99  2  3  4  5  6]
# Copy Array: [1 2 3 4 5 6]
