# %%
#Iterators
num=[1,2,3]
iterator=iter(num)

print(next(iterator))
print(next(iterator))
print(next(iterator))
# Out:
# 1
# 2
# 3

# %%
#closure

def outer_function(multi):
    def inner_function(value):
        return value * multi
    return inner_function

times3=outer_function(3)
print(times3(5))
# Out:
# 15

# %%
#Generator

def generator_number():
    for i in range(1,6):
        yield i

gen=generator_number()
for num in gen:
    print(num)
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
#Decorator

def logger(funct):
    def wrapper():
        print(f"Running {funct.__name__}....")
        funct()
        print(f"{funct.__name__} finished!")
    return wrapper

@logger
def greet():
    print("Hello Python Learners!!")
greet()

@logger
def greet2():
    print("Hello Java Learners")
greet2()
# Out:
# Running greet....
# Hello Python Learners!!
# greet finished!
# Running greet2....
# Hello Java Learners
# greet2 finished!

# %%
#Generator Function
def temperature_stream():
    for temp in range(25,45):
        yield temp

#Closure to hold threshold
def threshold_checker(threshold):
    def check(temp):
        return temp>threshold
    return check

#Decorator Function

def logger(func):
    def wrapper(*args,**kwargs):
        print(f"Checking {args[0]} C..")
        result=func(*args,**kwargs)
        if result:
            print(f"Alert: Temperature {args[0]} C exceeds threshold!")
        return result
    return wrapper

@logger
def analyze_temperature(temp):
    checker=threshold_checker(38)
    return checker(temp)

for t in temperature_stream():
    analyze_temperature(t)
# Out:
# Checking 25 C..
# Checking 26 C..
# Checking 27 C..
# Checking 28 C..
# Checking 29 C..
# Checking 30 C..
# Checking 31 C..
# Checking 32 C..
# Checking 33 C..
# Checking 34 C..
# Checking 35 C..
# Checking 36 C..
# Checking 37 C..
# Checking 38 C..
# Checking 39 C..
# Alert: Temperature 39 C exceeds threshold!
# Checking 40 C..
# Alert: Temperature 40 C exceeds threshold!
# Checking 41 C..
# Alert: Temperature 41 C exceeds threshold!
# Checking 42 C..
# Alert: Temperature 42 C exceeds threshold!
# Checking 43 C..
# Alert: Temperature 43 C exceeds threshold!
# Checking 44 C..
# Alert: Temperature 44 C exceeds threshold!

# %%
#Generator Function
def stock_price():
    keys=[]
    values=[]
    company={"A":260,"B":254,"C":279,"D":258,"E":298}
    for key, value in company.items():
        yield key,value
        keys.append(key)
        values.append(value)

#Closure to hold threshold
def threshold_checker(threshold):
    def check(value):
        return value<threshold
    return check

#Decorator Function

def logger(func):
    def wrapper(*args,**kwargs):
        key, value = args
        print(f"Checking {key}:{value}")
        result=func(*args,**kwargs)
        if result:
            print(f"Alert: {key} Company Prices have decreased below threshold !")
            print(f"Prices are:{value}")
        return result
    return wrapper

@logger
def analyze_temperature(key, value):
    checker=threshold_checker(275)
    return checker(value)

for key, value in stock_price():
    analyze_temperature(key, value)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[13], line 35
#      32     return checker(value)
#      34 for key, value in stock_price():
# ---> 35     analyze_temperature(key, value)
#
# TypeError: 'NoneType' object is not callable
