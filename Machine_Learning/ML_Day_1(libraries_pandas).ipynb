# %%
import pandas as pd
print(pd.__version__)
# Out:
# 2.3.3

# %%
list1=[1,2,3,4,5]
ser=pd.Series(list1,index=['a','b','c','d','e'])
ser
# Out:
# a    1
# b    2
# c    3
# d    4
# e    5
# dtype: int64

# %%
data={
    "Name":["AD","AB","AC","AF","AM"],
    "Age":[28,36,24,23,21],
    "Salary":[2000,3000,4000,5000,6000]
}

df=pd.DataFrame(data)
df
# Out:
#   Name  Age  Salary
# 0   AD   28    2000
# 1   AB   36    3000
# 2   AC   24    4000
# 3   AF   23    5000
# 4   AM   21    6000

# %%
df.head(2)
# Out:
#   Name  Age  Salary
# 0   AD   28    2000
# 1   AB   36    3000

# %%
df.tail(2)
# Out:
#   Name  Age  Salary
# 3   AF   23    5000
# 4   AM   21    6000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Name    5 non-null      object
#  1   Age     5 non-null      int64
#  2   Salary  5 non-null      int64
# dtypes: int64(2), object(1)
# memory usage: 252.0+ bytes

# %%
df.describe()
# Out:
#             Age      Salary
# count   5.00000     5.00000
# mean   26.40000  4000.00000
# std     5.94138  1581.13883
# min    21.00000  2000.00000
# 25%    23.00000  3000.00000
# 50%    24.00000  4000.00000
# 75%    28.00000  5000.00000
# max    36.00000  6000.00000

# %%
df.shape
# Out:
# (5, 3)

# %%
df.columns
# Out:
# Index(['Name', 'Age', 'Salary'], dtype='object')

# %%
df.Age
# Out:
# 0    28
# 1    36
# 2    24
# 3    23
# 4    21
# Name: Age, dtype: int64

# %%
df.Name
# Out:
# 0    AD
# 1    AB
# 2    AC
# 3    AF
# 4    AM
# Name: Name, dtype: object

# %%
print(df[['Age','Name']])
# Out:
#    Age Name
# 0   28   AD
# 1   36   AB
# 2   24   AC
# 3   23   AF
# 4   21   AM

# %%
df.iloc[0]
# Out:
# Name        AD
# Age         28
# Salary    2000
# Name: 0, dtype: object

# %%
df.iloc[1:3]
# Out:
#   Name  Age  Salary
# 1   AB   36    3000
# 2   AC   24    4000

# %%
df.loc[0:3,['Name','Age']]
# Out:
#   Name  Age
# 0   AD   28
# 1   AB   36
# 2   AC   24
# 3   AF   23

# %%
df['Tax']=df['Salary']*0.10
df
# Out:
#   Name  Age  Salary    Tax
# 0   AD   28    2000  200.0
# 1   AB   36    3000  300.0
# 2   AC   24    4000  400.0
# 3   AF   23    5000  500.0
# 4   AM   21    6000  600.0

# %%
df['Salary']=df['Salary']+1000
df
# Out:
#   Name  Age  Salary    Tax
# 0   AD   28    3000  200.0
# 1   AB   36    4000  300.0
# 2   AC   24    5000  400.0
# 3   AF   23    6000  500.0
# 4   AM   21    7000  600.0

# %%
df.drop('Tax',axis=1,inplace=True)
df
# Out:
#   Name  Age  Salary
# 0   AD   28    3000
# 1   AB   36    4000
# 2   AC   24    5000
# 3   AF   23    6000
# 4   AM   21    7000

# %%
df.loc[2,'Age']=None
df
# Out:
#   Name   Age  Salary
# 0   AD  28.0    3000
# 1   AB  36.0    4000
# 2   AC   NaN    5000
# 3   AF  23.0    6000
# 4   AM  21.0    7000

# %%
df.isna()
# Out:
#     Name    Age  Salary
# 0  False  False   False
# 1  False  False   False
# 2  False   True   False
# 3  False  False   False
# 4  False  False   False

# %%
df['Age']=df['Age'].fillna(df['Age'].mode())
df
# Out:
#   Name   Age  Salary
# 0   AD  28.0    3000
# 1   AB  36.0    4000
# 2   AC  28.0    5000
# 3   AF  23.0    6000
# 4   AM  21.0    7000

# %%
df.dropna()
# Out:
#   Name   Age  Salary
# 0   AD  28.0    3000
# 1   AB  36.0    4000
# 2   AC  28.0    5000
# 3   AF  23.0    6000
# 4   AM  21.0    7000

# %%
con1=df[df['Age']<30]
con1
# Out:
#   Name   Age  Salary
# 0   AD  28.0    3000
# 2   AC  28.0    5000
# 3   AF  23.0    6000
# 4   AM  21.0    7000

# %%
con2=df[(df['Age']<30) & (df['Salary']>4000)]
con2
# Out:
#   Name   Age  Salary
# 2   AC  28.0    5000
# 3   AF  23.0    6000
# 4   AM  21.0    7000

# %%
df.sort_values(by='Age',ascending=True)
# Out:
#   Name   Age  Salary
# 4   AM  21.0    7000
# 3   AF  23.0    6000
# 2   AC  28.0    5000
# 0   AD  28.0    3000
# 1   AB  36.0    4000

# %%
df.sort_values(by=['Age','Salary'], ascending=False)
# Out:
#   Name   Age  Salary
# 1   AB  36.0    4000
# 2   AC  28.0    5000
# 0   AD  28.0    3000
# 3   AF  23.0    6000
# 4   AM  21.0    7000

# %%
df['Ranking']=df['Age'].rank(ascending=False)
df
# Out:
#   Name   Age  Salary  Ranking
# 0   AD  28.0    3000      2.5
# 1   AB  36.0    4000      1.0
# 2   AC  28.0    5000      2.5
# 3   AF  23.0    6000      4.0
# 4   AM  21.0    7000      5.0

# %%
group1=df.groupby('Age')['Salary'].mean()
group1
# Out:
# Age
# 21.0    7000.0
# 23.0    6000.0
# 28.0    4000.0
# 36.0    4000.0
# Name: Salary, dtype: float64

# %%
group2=df.groupby('Age').agg({'Salary':['mean','max','min']})
group2
# Out:
#       Salary
#         mean   max   min
# Age
# 21.0  7000.0  7000  7000
# 23.0  6000.0  6000  6000
# 28.0  4000.0  5000  3000
# 36.0  4000.0  4000  4000

# %%
dept_data=pd.DataFrame({
    "Name":["AD","AB","AC","AF","AM"],
    "Department":["HR","IT","Finance","IT","HR"]
})

merged=pd.merge(df,dept_data,on="Name")
merged
# Out:
#   Name   Age  Salary  Ranking Department
# 0   AD  28.0    3000      2.5         HR
# 1   AB  36.0    4000      1.0         IT
# 2   AC  28.0    5000      2.5    Finance
# 3   AF  23.0    6000      4.0         IT
# 4   AM  21.0    7000      5.0         HR

# %%
df1=df.head(2)
df2=df.tail(2)

combine=pd.concat([df1,df2])
combine
# Out:
#   Name   Age  Salary  Ranking
# 0   AD  28.0    3000      2.5
# 1   AB  36.0    4000      1.0
# 3   AF  23.0    6000      4.0
# 4   AM  21.0    7000      5.0

# %%
df['Salary'].mean()
df['Salary'].min()
df['Salary'].max()
# Out:
# np.int64(7000)

# %%
df['Joinning_Date']=pd.date_range(start='2020-01-01', periods=len(df), ferq='D')

df["Joinning_Year"]=df['Joinning_Date'].dt.year

df[["Name","Joinning_Date","Joinning_Year"]]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[165], line 1
# ----> 1 df['Joinning_Date']=pd.date_range(start='2020-01-01', periods=len(df), ferq='D')
#       3 df["Joinning_Year"]=df['Joinning_Date'].dt.year
#       5 df[["Name","Joinning_Date","Joinning_Year"]]
#
# File c:\Users\Admin\Desktop\Python Basics\.venv\Lib\site-packages\pandas\core\indexes\datetimes.py:1008, in date_range(start, end, periods, freq, tz, normalize, name, inclusive, unit, **kwargs)
#    1005 if freq is None and com.any_none(periods, start, end):
#    1006     freq = "D"
# -> 1008 dtarr = DatetimeArray._generate_range(
#    1009     start=start,
#    1010     end=end,
#    1011     periods=periods,
#    1012     freq=freq,
#    1013     tz=tz,
#    1014     normalize=normalize,
#    1015     inclusive=inclusive,
#    1016     unit=unit,
#    1017     **kwargs,
#    1018 )
# ...

# %%
df.to_csv('Final_output.csv',index=False)

# %%
import os

path=os.getcwd()
print(path)
# Out:
# c:\Users\Admin\Desktop\Python Basics
