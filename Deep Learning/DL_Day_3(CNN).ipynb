# %%
import cv2
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
file="/content/dataset/training_set/dogs/dog.21.jpg"

# %%
img=cv2.imread(file)

# %%
img
# Out:
# array([[[ 46,  44,  64],
#         [ 37,  38,  58],
#         [ 36,  40,  64],
#         ...,
#         [254, 254, 254],
#         [254, 254, 254],
#         [254, 254, 254]],
#
#        [[ 49,  47,  66],
#         [ 41,  40,  60],
#         [ 37,  42,  63],
#         ...,
#         [254, 254, 254],
#         [254, 254, 254],
#         [254, 254, 254]],
#
#        [[ 54,  53,  69],
#         [ 45,  45,  61],
#         [ 40,  47,  64],
#         ...,
#         [254, 254, 254],
#         [254, 254, 254],
#         [254, 254, 254]],
#
#        ...,
#
#        [[ 78,  69,  66],
#         [118, 109, 106],
#         [153, 144, 141],
#         ...,
#         [ 11,  11,  11],
#         [ 11,  11,  11],
#         [ 11,  11,  11]],
#
#        [[197, 188, 185],
#         [212, 203, 200],
#         [215, 203, 201],
#         ...,
#         [ 11,  11,  11],
#         [ 11,  11,  11],
#         [ 12,  12,  12]],
#
#        [[244, 235, 232],
#         [247, 238, 235],
#         [232, 220, 218],
# ...

# %%
img.shape
# Out:
# (499, 327, 3)

# %%
img[0][0]
# Out:
# array([211, 224, 238], dtype=uint8)

# %%
from google.colab.patches import cv2_imshow
cv2_imshow(img)
# cv2.imshow is disabled in Colab, so waitkey and destroyAllWindows are not needed either.
# waitkey=cv2.waitkey(0)
# if waitkey==27:
#   cv2.destroyAllWindows()
# Out:
# <PIL.Image.Image image mode=RGB size=415x499>

# %%
cv2_imshow(gray_img)
# Out:
# <PIL.Image.Image image mode=L size=415x499>

# %%
plt.imshow(img)

# %%
gray_img=cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)

# %%
gray_img.shape
# Out:
# (499, 415)

# %%
plt.imshow(gray_img,cmap='gray')

# %%
resized_img=cv2.resize(img,(50,50))

# %%
plt.imshow(resized_img)

# %%
#Array To Image

# %%
[red,yellow,orange]
[blue,black,white]
[green,cyan,magenta]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_418/3226528321.py in <cell line: 0>()
# ----> 1 [red,yellow,orange]
#       2 [blue,black,white]
#       3 [green,cyan,magenta]
#
# NameError: name 'red' is not defined

# %%
np_array=np.array([[[255,0,0],[255,255,0],[255,128,0]],
                  [[0,0,255],[0,0,0],[255,255,255]],
                  [[0,255,0],[0,255,255],[255,0,255]]])

# %%
plt.imshow(np_array)
