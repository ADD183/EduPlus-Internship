# %%
import tensorflow as tf
print("Tensorflow version:",tf.__version__)
# Out:
# Tensorflow version: 2.20.0

# %%
scalar=tf.constant(42)
vector=tf.constant([1,2,3,4])
matrix=tf.constant([[1,2],[3,4]])
tensor_3d=tf.constant([[[1,2],[3,4]],[[5,6],[7,8]]])

print(f"Scalar shape:{scalar.shape} value:{scalar.numpy()}")
print(f"Vector shape:{vector.shape} value:{vector.numpy()}")
print(f"Matrix shape:{matrix.shape} value:{matrix.numpy()}")
print(f"tensor_3d shape:{tensor_3d.shape} value:{tensor_3d.numpy()}")
# Out:
# Scalar shape:() value:42
# Vector shape:(4,) value:[1 2 3 4]
# Matrix shape:(2, 2) value:[[1 2]
#  [3 4]]
# tensor_3d shape:(2, 2, 2) value:[[[1 2]
#   [3 4]]
#
#  [[5 6]
#   [7 8]]]

# %%
print("Tensor Rank:",tf.rank(matrix).numpy())
print("Tensor Size:",tf.size(matrix).numpy())
print("Tensor Type:",tf.dtype(matrix))
# Out:
# Tensor Rank: 2
# Tensor Size: 4
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[8], line 3
#       1 print("Tensor Rank:",tf.rank(matrix).numpy())
#       2 print("Tensor Size:",tf.size(matrix).numpy())
# ----> 3 print("Tensor Type:",tf.dtype(matrix))
#
# AttributeError: module 'tensorflow' has no attribute 'dtype'

# %%
a=tf.constant([[1,2],[3,4]])
b=tf.constant([[5,6],[7,8]])

print("Sum:\n",tf.add(a,b).numpy())
print("Multiply Elementwise:\n",tf.multiply(a,b).numpy())
print("Multiply In Matrix form:\n",tf.matmul(a,b).numpy())
# Out:
# Sum:
#  [[ 6  8]
#  [10 12]]
# Multiply Elementwise:
#  [[ 5 12]
#  [21 32]]
# Multiply In Matrix form:
#  [[19 22]
#  [43 50]]

# %%
x=tf.constant([1.0,2.0,3.0])

print("Squares:",tf.square(x).numpy())
print("Square roots:",tf.sqrt(x).numpy())
print("Exponential:",tf.exp(x).numpy())
# Out:
# Squares: [1. 4. 9.]
# Square roots: [1.        1.4142135 1.7320508]
# Exponential: [ 2.7182817  7.389056  20.085537 ]

# %%
weights=tf.Variable([[1.0,2.0],[3.0,4.0]], name="weights")
bias=tf.Variable([0.5,0.5])

print(f"Initial Weights are:\n{weights.numpy()}")
print(f"Initial Bias are:{bias.numpy()}")
# Out:
# Initial Weights are:
# [[1. 2.]
#  [3. 4.]]
# Initial Bias are:[0.5 0.5]

# %%
weights.assign([[2.0,3.0],[4.0,5.0]])

print("Changed values are:\n",weights.numpy())
# Out:
# Changed values are:
#  [[2. 3.]
#  [4. 5.]]

# %%
weights.assign_add([[1.0,1.0],[2.0,3.5]])

print("Changed values are:\n",weights.numpy())
# Out:
# Changed values are:
#  [[3.  4. ]
#  [6.  8.5]]

# %%
bias.assign_add([1.0,2.0])
print(bias.numpy())
# Out:
# [1.5 2.5]

# %%
import nltk

# %%
nltk.download('punkt')   #For tokenization
nltk.download('stopwords')
nltk.download('wordnet')                #
nltk.download('average_perceptron_tagger')      #for pos tagging
nltk.download('movie_reviews')          #example for ML
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Admin\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping tokenizers\punkt.zip.
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Admin\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping corpora\stopwords.zip.
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Admin\AppData\Roaming\nltk_data...
# [nltk_data] Error loading average_perceptron_tagger: Package
# [nltk_data]     'average_perceptron_tagger' not found in index
# [nltk_data] Downloading package movie_reviews to
# [nltk_data]     C:\Users\Admin\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping corpora\movie_reviews.zip.
# True

# %%
#Step:2 Tokenization 

from nltk.tokenize import word_tokenize, sent_tokenize

text="Natural Language Processing with NLTK is fun and educational. Let's learn it step by step."

sentences=sent_tokenize(text)
print("Sentences are:",sentences)
# Out:
# Sentences are: ['Natural Language Processing with NLTK is fun and educational.', "Let's learn it step by step."]

# %%
import nltk
nltk.download('punkt_tab')
# Out:
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     C:\Users\Admin\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping tokenizers\punkt_tab.zip.
# True

# %%
#Step:2 Tokenization 

from nltk.tokenize import word_tokenize, sent_tokenize

text="Natural Language Processing with NLTK is fun and educational. Let's learn it step by step."

sentences=sent_tokenize(text)
print("Sentences are:",sentences)

words=word_tokenize(text)
print("Words are:",words)
# Out:
# Sentences are: ['Natural Language Processing with NLTK is fun and educational.', "Let's learn it step by step."]
# Words are: ['Natural', 'Language', 'Processing', 'with', 'NLTK', 'is', 'fun', 'and', 'educational', '.', 'Let', "'s", 'learn', 'it', 'step', 'by', 'step', '.']

# %%
#Step 3: Removing Stopwords
from nltk.corpus import stopwords

stop_words=set(stopwords.words('english'))
filtered_words=[ w for w in words if w.lower() not in stop_words]

print("words after removing stopwords:\n",filtered_words)
# Out:
# words after removing stopwords:
#  ['Natural', 'Language', 'Processing', 'NLTK', 'fun', 'educational', '.', 'Let', "'s", 'learn', 'step', 'step', '.']

# %%
#Step 4: Stemming

from nltk.stem import PorterStemmer

stemmer=PorterStemmer()
stemmed_words = [stemmer.stem(w) for w in filtered_words]

print("Stemmed words are:\n",stemmed_words)
# Out:
# Stemmed words are:
#  ['natur', 'languag', 'process', 'nltk', 'fun', 'educ', '.', 'let', "'s", 'learn', 'step', 'step', '.']

# %%
#Step 5: Lemmatization

from nltk.stem import WordNetLemmatizer

lemmatizer=WordNetLemmatizer()
lemmatized_words=[lemmatizer.lemmatize(w) for w in filtered_words]

print(lemmatized_words)
# Out:
# ['Natural', 'Language', 'Processing', 'NLTK', 'fun', 'educational', '.', 'Let', "'s", 'learn', 'step', 'step', '.']

# %%
import nltk
nltk.download('averaged_perceptron_tagger_eng')
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger_eng to
# [nltk_data]     C:\Users\Admin\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping taggers\averaged_perceptron_tagger_eng.zip.
# True

# %%
#Step 6:Parts of Speech

pos_tags=nltk.pos_tag(filtered_words)
print("Parts of Speech:\n",pos_tags)
# Out:
# Parts of Speech:
#  [('Natural', 'JJ'), ('Language', 'NNP'), ('Processing', 'NNP'), ('NLTK', 'NNP'), ('fun', 'VBD'), ('educational', 'JJ'), ('.', '.'), ('Let', 'VB'), ("'s", 'POS'), ('learn', 'JJ'), ('step', 'NN'), ('step', 'NN'), ('.', '.')]

# %%
#Step 7:Frequency Distribution

from nltk import FreqDist

freq_dist=FreqDist(filtered_words)
print("words Frequency:\n")
for words,freq in freq_dist.most_common(5):
    print(f"{words}:{freq}")

freq_dist.plot(10,title="Top 10 word Frequency")
# Out:
# words Frequency:
#
# .:2
# step:2
# Natural:1
# Language:1
# Processing:1
# <Axes: title={'center': 'Top 10 word Frequency'}, xlabel='Samples', ylabel='Counts'>
